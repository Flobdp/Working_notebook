# %%
import pandas as pd

data = pd.read_csv('export-inventaires-opendata-31-08-2023.csv', delimiter=';')

# %%
data
# Out:
#                                         Id Méthode BEGES (V4,V5)  \
# 0     93708e2c-b1cd-11ed-8fce-005056b7acd1                    v4
# 1     9370955a-b1cd-11ed-8fce-005056b7acd1                    v4
# 2     9370988a-b1cd-11ed-8fce-005056b7acd1                    v4
# 3     93709cb8-b1cd-11ed-8fce-005056b7acd1                    v4
# 4     93709e81-b1cd-11ed-8fce-005056b7acd1                    v4
# ...                                    ...                   ...
# 5573  5a2b2e99-e581-4488-a135-4ed1c05fae45                    v5
# 5574  dc55d389-c039-4554-88ee-8827f89dc8ff                    v5
# 5575  185c0708-d17c-4699-817b-2140a9ac37f3                    v5
# 5576  a9d11959-3cb0-4c63-89a7-f88883eeec57                    v5
# 5577  6a10a0f7-d6e0-4a54-8972-d62699adee1d                    v5
#
#      Date de publication                      Type de structure  \
# 0             04/03/2015                             Entreprise
# ...

# %%
# Get the column names
column_names = data.columns.tolist()

# Print all 94 column names
for column_name in column_names:
    print(column_name)
# Out:
# Id
# Méthode BEGES (V4,V5)
# Date de publication
# Type de structure
# Type de collectivité
# Raison sociale
# SIREN principal
# APE(NAF) associé
# Libellé
# Nombre de salariés/d'agents
# Population
# Région
# Code département
# Département
# Structure obligée
# Mode de consolidation
# Année de reporting
# Assujetti DPEF/PCAET ?
# Lien DPEF/PCAET
# Seuil d'importance retenu (%)
# Niveau d'influence
# Importance stratégique et vulnérabilités
# Lignes directrices spécifiques au secteur
# Sous-traitance
# Engagement du personnel
# Justification des postes d'émissions indirectes écartés
# Emissions publication P1.1
# Emissions publication P1.2
# Emissions publication P1.3
# Emissions publication P1.4
# Emissions publication P1.5
# Emissions publication P2.1
# Emissions publication P2.2
# Emissions publication P3.1
# Emissions publication P3.2
# Emissions publication P3.3
# Emissions publication P3.4
# Emissions publication P3.5
# Emissions publication P4.1
# Emissions publication P4.2
# ...
